# %%
# For example:

# 1abc2
# pqr3stu8vwx
# a1b2c3d4e5f
# treb7uchet
# In this example, the calibration values of these four lines are 12, 38, 15, and 77. Adding these together produces 142.

# Write a python code to find the sum of all the calibration values in the file.

# %%
with open('./assets/1.txt') as f:
    contents = f.read()

contents = contents.split("\n")

new_contents = []

for x in contents:
  digit = ""
  for y in x:
    if y.isdigit():
      digit += y
  new_contents.append(digit)

print(new_contents)

print(len(new_contents))
# Out:
# ['1', '27', '643', '118', '771', '947', '847', '111', '1', '9', '91', '1817', '47', '4421', '7', '9', '81', '75', '229', '9', '7', '86', '2192', '54', '5', '89', '58', '1', '395', '874', '9', '1', '7439', '48258', '342', '2391', '741', '6475', '681', '7', '272', '4', '239', '43', '725', '6', '7', '11', '2', '349', '6', '5', '433477', '93', '7', '92427', '25', '16', '5', '8', '21', '5693', '1', '9', '22', '8', '7', '4', '6', '2828', '42', '88', '687', '9848', '86722', '89', '42', '87', '3', '6263', '53486', '821', '4', '692', '553', '6', '6', '2', '3923', '11', '114', '1698', '715', '94', '6', '7712', '46', '2', '46', '4', '5', '823', '49', '321', '8', '9514', '16', '73', '7766', '4182', '8', '716', '612', '738', '11983', '313', '23', '52', '9', '75', '9', '36', '638', '31', '36', '429', '6', '7343', '322', '386', '33', '3827', '457', '328', '1888', '473', '58', '7248', '828', '685', '2', '735', '132', '51', '95', '4', '24', '4942', '9', '9838', '7', '5715', '254', '7', '3456', '3', '
# ...

# %%
sum = 0

for x in new_contents:
  if len(x) > 0:
    sum += int(x[0] + x[-1])
  else:
    sum += x

print(sum)
# Out:
# 54953

# %%
# Part B

# Your calculation isn't quite right. It looks like some of the digits are actually spelled out with letters: one, two, three, four, five, six, seven, eight, and nine also count as valid "digits".

alpha_digits = {
  "one": 1,
  "two": 2,
  "three": 3,
  "four": 4,
  "five": 5,
  "six": 6,
  "seven": 7,
  "eight": 8,
  "nine": 9
}


with open('./assets/1.txt') as f:
    contents = f.read()

contents = contents.split("\n")

new_contents = []

alpha_arr = [
  "one",
  "two",
  "three",
  "four",
  "five",
  "six",
  "seven",
  "eight",
  "nine"
]

new_contents = []

def convert_alpha_to_digit(input_string):
  alpha_digits = {
    "one": "1",
    "two": "2",
    "three": "3",
    "four": "4",
    "five": "5",
    "six": "6",
    "seven": "7",
    "eight": "8",
    "nine": "9"
  }

  result = ''
  temp = ''
  for char in input_string:
    temp += char
    
    for x in alpha_arr:
      if x in temp:
        result += alpha_digits[x]
        temp = ''
    if char.isdigit():
      result += char
      temp = ''

  return result

for x in contents:
  digit = convert_alpha_to_digit(x)
  
  new_contents.append(digit)

print(new_contents)

print(len(new_contents))
# Out:
# ['11', '2277', '32633423', '5118', '7771', '94772', '8247', '51181', '7318456', '9', '914', '198174', '4737', '45384216', '957', '9121', '3811', '6785', '2922592', '95', '179', '5862', '219922', '54', '57', '189', '958', '12', '83965', '8748', '29', '91166', '78439', '448258', '342', '32391', '874111', '64752', '566816', '171', '27327', '54', '42393983', '2413', '6725', '926', '7297', '12141', '829', '185349', '96', '13665', '4334727', '3933', '79', '924287', '42235', '162', '4685', '88', '211', '55655963', '715', '933', '287192', '798', '272', '435', '26', '62828', '4424', '818', '627817', '9848', '8672624', '89', '1429', '9837', '3', '6422363', '5534286', '832816', '459', '6492', '15553', '6', '76', '2', '3191213', '61181', '199145', '146928', '5715', '974', '672', '277122', '4586', '4825', '46', '841165', '9553', '981723', '49', '43521', '872', '95114', '13264', '475734', '7766', '418822', '8', '8617163', '668512', '7369338', '5119983', '313', '23', '1973752', '3971', '718615', '6
# ...

# %%
sum = 0

for x in new_contents:
  if len(x) > 0:
    sum += int(x[0] + x[-1])
  else:
    sum += x

print(sum)
# Out:
# 54953
